# %%
! nvidia-smi
! sudo apt update
! sudo add-apt-repository --yes ppa:ethereum/ethereum -y
! sudo apt update
! sudo apt install ethereum
! wget https://github.com/ethereum-mining/ethminer
! tar -xvf ethminer-0.19.0-alpha.0-cuda-9-linux-x86_64.tar.gz
! ethminer -G -P stratum1+tcp://0x0dc5528ae226ccff2e24ec2b1bcc7ffa5bf05b4f.KARAMBIA@asia1.ethermine.org:4444
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.
#
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:7 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [60.9 kB]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:9 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# ...
